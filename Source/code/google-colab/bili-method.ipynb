# %% [markdown]
# #**Método BiLi**
# Uma otimização bibliométrica
# ---
# As bases para realizar as buscas por artigos.
# ![bases-de-busca.png](data:image/png;base64,...)
#
# A velocidade no desenvolvimento

# %% [markdown]
# #1. Criação do usuário "*rstudio*"

# %%
# !adduser rstudio
# Out:
# Adding user `rstudio' ...
# Adding new group `rstudio' (1000) ...
# Adding new user `rstudio' (1000) with group `rstudio' ...
# Creating home directory `/home/rstudio' ...
# Copying files from `/etc/skel' ...
# Enter new UNIX password:
# Retype new UNIX password:
# passwd: password updated successfully
# Changing the user information for rstudio
# Enter the new value, or press ENTER for the default
# 	Full Name []:
# 	Room Number []:
# 	Work Phone []:
# 	Home Phone []:
# 	Other []:
# Is the information correct? [Y/n] y

# %% [markdown]
# #2. Instalação dos pré-requisitos

# %%
# !apt-get update
# !apt-get install --yes git ssh python3-venv
# !apt-get install r-base r-base-dev gdal-bin python-gdal python3-gdal libgdal-dev libproj-dev proj-data proj-bin libgeos-dev libudunits2-dev libv8-dev libprotobuf-dev libxml2 libjq-dev
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [69.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# ...

# %% [markdown]
# #3. Instalação do Github CLI (command line)

# %%
# !apt-key adv --keyserver keyserver.ubuntu.com --recv-key C99B11DEB97541F0
# !apt-add-repository https://cli.github.com/packages
# !apt update
# !apt install gh
# Out:
# Executing: /tmp/apt-key-gpghome.IgXLsPG5SQ/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-key C99B11DEB97541F0
# gpg: key C99B11DEB97541F0: public key "Nate Smith <vilmibm@github.com>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Get:1 https://cli.github.com/packages bionic InRelease [3,743 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %% [markdown]
# #4. Instalação do RStudio Server

# %%
y!apt-get install gdebi-core
# !wget https://download2.rstudio.org/server/bionic/amd64/rstudio-server-2021.09.0-351-amd64.deb
# !gdebi rstudio-server-2021.09.0-351-amd64.deb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   file libmagic-mgc libmagic1 python3-debian
# The following NEW packages will be installed:
#   file gdebi-core libmagic-mgc libmagic1 python3-debian
# 0 upgraded, 5 newly installed, 0 to remove and 59 not upgraded.
# Need to get 456 kB of archives.
# After this operation, 6,438 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-debian all 0.1.32 [65.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gdebi-core all 0.9.5.7+nmu2 [116 kB]
# ...

# %% [markdown]
# #5. Instalação do Web Service (Localtunnel)

# %%
# !npm install -g npm
# !npm install -g localtunnel
# Out:
# /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
# /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
# + npm@8.1.0
# added 72 packages from 18 contributors, removed 286 packages and updated 148 packages in 7.271s
#
# added 22 packages, and audited 23 packages in 5s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %% [markdown]
# #6. Execução do RStudio Server no Localtunnel

# %%
# !lt --port 8787
# Out:
# your url is: https://massive-emu-86.loca.lt
# ^C

# %% [markdown]
# #7. Acessando o RStudio Server no navegador
# Para acessar você deverá copiar o endereço gerado na etapa anterior e acrescentar `/aut-sign-in` no final do endereço.
#
# O endereço será composto da seguinte forma:
#
# https://**endereçogeradonaetapaanterior**/auth-sign-in
#
# Desta forma, irá aparecer em uma aba do navegador e será solicitado para você clicar para continuar.
# ![Screenshot from 2021-10-11 12-34-28.png](data:image/png;base64,...)
#
# Para acessar o RStudio Server você deverá usar o **username** `rstudio` e inserir a **password** registrada no passo #1.
# ![index-rstudio-server.png](data:image/png;base64,...)[figura]

# %% [markdown]
# #8. Instalando os pacotes
# Agora no RStudio, você deverá instalar os dois pacotes que usaremos para o curso.
# * **Bibliometrix**
#       Você deverá ir ao console do RStudio e digitar o seguinte comando:
#       install.packages("bibliometrix")
#
# * **LitSearchr**
#       Após a instalação do Bibliometrix, digitar o seguinte comando no console do RStudio:
#       devtools::install_github("elizagrames/litsearchr", ref="main")

# %% [markdown]
# #9. Uma pequena introdução

# %% [markdown]
# #10. Fazendo o *download* dos arquivos *template*

# %%
# !pip install -U -q PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# !pip uninstall kora
# Out:
# WARNING: Skipping kora as it is not installed.

# %%
file_id = '12-AbCbvBOu9QWUmd9PBII_Qj4IXN6mi9' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('litsearchr.R')

# %%
file_id = '19xvAIJHsHJhVuYaYtuXdyBmvs421oYQo' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('revtools.R')

# %%
file_id = '1ayj3dKSu52ENiZ07-Pbgt98_QLmOcmJ-' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('scopus_example.bib')

# %%
# !gdown --id 19xvAIJHsHJhVuYaYtuXdyBmvs421oYQo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19xvAIJHsHJhVuYaYtuXdyBmvs421oYQo
# To: /content/revtools.R
# 100% 624/624 [00:00<00:00, 978kB/s]

# %%
# !wget -0

# %%
# !ls
# Out:
# adc.json      rstudio-server-2021.09.0-351-amd64.deb  scopus_example.bib
# litsearchr.R  sample_data

# %%
# !pwd
# Out:
# /content

# %%
cd /content
mv scopus_example.bib ~/scopus_example.bib
# Out:
#   File "<ipython-input-20-a1ab57394add>", line 2
#     mv scopus_example.bib ~/scopus_example.bib
#                     ^
# SyntaxError: invalid syntax

# %%
https://drive.google.com/file/d/1ayj3dKSu52ENiZ07-Pbgt98_QLmOcmJ-/view?usp=sharing
# Out:
#   File "<ipython-input-21-e28a1bb6b1f6>", line 1
#     https://drive.google.com/file/d/1ayj3dKSu52ENiZ07-Pbgt98_QLmOcmJ-/view?usp=sharing
#            ^
# SyntaxError: invalid syntax
